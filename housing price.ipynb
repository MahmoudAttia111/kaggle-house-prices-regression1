# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy.stats import norm 
import numpy as np 
from sklearn.preprocessing import StandardScaler
from scipy import stats 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import joblib
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train = pd.read_csv(r"D:\data science\project kaggle\project Regression SalePrice\train.csv")
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(train['SalePrice']);

# %%
print (f"skewness: {train['SalePrice'].skew()}")
print(f"kurtosis: {train['SalePrice'].kurt()}")
# Out:
# skewness: 1.8828757597682129
# kurtosis: 6.536281860064529

# %%
feature1 = 'GrLivArea'
data = pd.concat([train['SalePrice'],train[feature1]],axis=1)
data.plot.scatter(x=feature1, y='SalePrice',ylim=(0,800000));

# %% [markdown]
# linear relationship

# %%
feature2 = 'TotalBsmtSF'
data = pd.concat([train['SalePrice'],train[feature2]],axis=1)
data.plot.scatter(x=feature2, y='SalePrice',ylim=(0,800000));

# %% [markdown]
#  ****linear relationship but changes

# %% [markdown]
# # Relationship with categorical features#

# %%
feature1 = 'OverallQual'
data = pd.concat([train['SalePrice'],train[feature1]],axis=1)
data.plot.scatter(x=feature1, y='SalePrice',ylim=(0,800000));
fi,axis=plt.subplots(figsize=(8,6))
fig=sns.boxplot(x=feature1,y='SalePrice',data=data)
fig.axis(ymin=0,ymax=800000)
# Out:
# (-0.5, 9.5, 0.0, 800000.0)

# %%
feature2 =  'YearBuilt'
data = pd.concat([train['SalePrice'],train[feature2]],axis=1)
data.plot.scatter(x=feature2, y='SalePrice',ylim=(0,800000));
fi,axis=plt.subplots(figsize=(8,6))
fig=sns.boxplot(x=feature2,y='SalePrice',data=data)
fig.axis(ymin=0,ymax=800000)
# Out:
# (-0.5, 111.5, 0.0, 800000.0)

# %% [markdown]
# **Not more effective******

# %% [markdown]
# # summary

# %% [markdown]
# 'GrLivArea' and 'TotalBsmtSF' seem to be linearly related with 'SalePrice'. Both relationships are positive, which means that as one variable increases, the other also increases. In the case of 'TotalBsmtSF', we can see that the slope of the linear relationship is particularly high.
# 'OverallQual' and 'YearBuilt' also seem to be related with 'SalePrice'. The relationship seems to be stronger in the case of 'OverallQual', where the box plot shows how sales prices increase with the overall quality.
# We just analysed four variables, but there are many other that we should analyse. The trick here seems to be the choice of the right features (feature selection) and not the definition of complex relationships between them (feature engineering).

# %% [markdown]
# **Correlation matrix (heatmap style)**

# %%
encoding=pd.get_dummies(train)
corr =   encoding.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corr, vmax=.8, square=True);
# corr1=train.corr()
# f,ax=plt.subplots(figsize(12,9))
# sns.heatmap(corr1, vmax=.8, asquare=True)

# %% [markdown]
# because data with catagerical data you had to handle it
# by method1: encoding all data
# or method2: encoding feature with cata only

# %%
import pandas as pd
import numpy as np

# Assuming your DataFrame is called 'train'
for col in train.columns:
    try:
        # Try converting the column to numeric.  Errors if it's not possible.
        pd.to_numeric(train[col], errors='raise')  # errors='raise' makes it throw an exception
        print(f"Column '{col}' is numeric.")
    except (TypeError, ValueError):
        # If conversion fails, print the column name and investigate
        print(f"Column '{col}' is NOT numeric. Contains values like: {train[col].unique()}")
# Out:
# Column 'Id' is numeric.
# Column 'MSSubClass' is numeric.
# Column 'MSZoning' is NOT numeric. Contains values like: ['RL' 'RM' 'C (all)' 'FV' 'RH']
# Column 'LotFrontage' is numeric.
# Column 'LotArea' is numeric.
# Column 'Street' is NOT numeric. Contains values like: ['Pave' 'Grvl']
# Column 'Alley' is NOT numeric. Contains values like: [nan 'Grvl' 'Pave']
# Column 'LotShape' is NOT numeric. Contains values like: ['Reg' 'IR1' 'IR2' 'IR3']
# Column 'LandContour' is NOT numeric. Contains values like: ['Lvl' 'Bnk' 'Low' 'HLS']
# Column 'Utilities' is NOT numeric. Contains values like: ['AllPub' 'NoSeWa']
# Column 'LotConfig' is NOT numeric. Contains values like: ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# Column 'LandSlope' is NOT numeric. Contains values like: ['Gtl' 'Mod' 'Sev']
# Column 'Neighborhood' is NOT numeric. Contains values like: ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Column 'Condition1' is NOT numeric. Contains values like: ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Column 'Condition2' is NOT numeric. Contains values like: ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# Column 'BldgType' is NOT numeric. Contains values like: ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# Column 'HouseStyle' is NOT numeric. Contains values like: ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# Column 'OverallQual' is numeric.
# Column 'OverallCond' is numeric.
# Column 'YearBuilt' is numeric.
# Column 'YearRemodAdd' is numeric.
# Column 'RoofStyle' is NOT numeric. Contains values like: ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# Column 'RoofMatl' is NOT numeric. Contains values like: ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
# Column 'Exterior1st' is NOT numeric. Contains values like: ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
# Column 'Exterior2nd' is NOT numeric. Contains values like: ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']
# Column 'MasVnrType' is NOT numeric. Contains values like: ['BrkFace' nan 'Stone' 'BrkCmn']
# Column 'MasVnrArea' is numeric.
# Column 'ExterQual' is NOT numeric. Contains values like: ['Gd' 'TA' 'Ex' 'Fa']
# Column 'ExterCond' is NOT numeric. Contains values like: ['TA' 'Gd' 'Fa' 'Po' 'Ex']
# Column 'Foundation' is NOT numeric. Contains values like: ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']
# Column 'BsmtQual' is NOT numeric. Contains values like: ['Gd' 'TA' 'Ex' nan 'Fa']
# Column 'BsmtCond' is NOT numeric. Contains values like: ['TA' 'Gd' nan 'Fa' 'Po']
# Column 'BsmtExposure' is NOT numeric. Contains values like: ['No' 'Gd' 'Mn' 'Av' nan]
# Column 'BsmtFinType1' is NOT numeric. Contains values like: ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
# Column 'BsmtFinSF1' is numeric.
# Column 'BsmtFinType2' is NOT numeric. Contains values like: ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Column 'BsmtFinSF2' is numeric.
# Column 'BsmtUnfSF' is numeric.
# Column 'TotalBsmtSF' is numeric.
# Column 'Heating' is NOT numeric. Contains values like: ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
# Column 'HeatingQC' is NOT numeric. Contains values like: ['Ex' 'Gd' 'TA' 'Fa' 'Po']
# Column 'CentralAir' is NOT numeric. Contains values like: ['Y' 'N']
# Column 'Electrical' is NOT numeric. Contains values like: ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
# Column '1stFlrSF' is numeric.
# Column '2ndFlrSF' is numeric.
# Column 'LowQualFinSF' is numeric.
# Column 'GrLivArea' is numeric.
# Column 'BsmtFullBath' is numeric.
# Column 'BsmtHalfBath' is numeric.
# Column 'FullBath' is numeric.
# Column 'HalfBath' is numeric.
# Column 'BedroomAbvGr' is numeric.
# Column 'KitchenAbvGr' is numeric.
# Column 'KitchenQual' is NOT numeric. Contains values like: ['Gd' 'TA' 'Ex' 'Fa']
# Column 'TotRmsAbvGrd' is numeric.
# Column 'Functional' is NOT numeric. Contains values like: ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev']
# Column 'Fireplaces' is numeric.
# Column 'FireplaceQu' is NOT numeric. Contains values like: [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# Column 'GarageType' is NOT numeric. Contains values like: ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# Column 'GarageYrBlt' is numeric.
# Column 'GarageFinish' is NOT numeric. Contains values like: ['RFn' 'Unf' 'Fin' nan]
# Column 'GarageCars' is numeric.
# Column 'GarageArea' is numeric.
# Column 'GarageQual' is NOT numeric. Contains values like: ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
# Column 'GarageCond' is NOT numeric. Contains values like: ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']
# Column 'PavedDrive' is NOT numeric. Contains values like: ['Y' 'N' 'P']
# Column 'WoodDeckSF' is numeric.
# Column 'OpenPorchSF' is numeric.
# Column 'EnclosedPorch' is numeric.
# Column '3SsnPorch' is numeric.
# Column 'ScreenPorch' is numeric.
# Column 'PoolArea' is numeric.
# Column 'PoolQC' is NOT numeric. Contains values like: [nan 'Ex' 'Fa' 'Gd']
# Column 'Fence' is NOT numeric. Contains values like: [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# Column 'MiscFeature' is NOT numeric. Contains values like: [nan 'Shed' 'Gar2' 'Othr' 'TenC']
# Column 'MiscVal' is numeric.
# Column 'MoSold' is numeric.
# Column 'YrSold' is numeric.
# Column 'SaleType' is NOT numeric. Contains values like: ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']
# Column 'SaleCondition' is NOT numeric. Contains values like: ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']
# Column 'SalePrice' is numeric.

# %%
train1 = pd.get_dummies(train, columns=['MSZoning'], prefix='MSZoning')
train1 = pd.get_dummies(train, columns=['Street'], prefix='Street')
#complete

# %% [markdown]
# **zoomed heatmap**

# %%
corr =   encoding.corr()
k = 10 #number of variables for heatmap high effiect
cols = corr.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef( corr[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# quality before heatmap we not interst with it but heatmap give it high importance

# %% [markdown]
# **Scatter plots between 'salePrice and correlated variables**

# %%
cols = corr.nlargest(k, 'SalePrice')['SalePrice'].index

cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'BsmtQual_Ex', 'TotRmsAbvGrd'],
#       dtype='object')

# %%
sns.set()
cols=['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
       'TotalBsmtSF' , 'FullBath', 'BsmtQual_Ex', 'TotRmsAbvGrd','YearBuilt']
sns.pairplot(corr[cols],size=2.5)
plt.show()

# %% [markdown]
# 1. **Relationship between SalePrice and OverallQual:**    Type of Relationship: A strong and clear positive   (direct) relationship.
# 2. **Impact of GrLivArea on SalePrice:**    Type of Relationship: Positive relationship.
# 3. **Impact of YearBuilt on SalePrice:**    Type of Relationship: Slight upward trend.

# %% [markdown]
# # Missing data

# %%
total = train.isnull().sum().sort_values(ascending=False)
percent = (train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missingData=pd.concat([total,percent],axis=1,keys=['Total','percent'])
missingData.head(20)
# Out:
#               Total   percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# MasVnrType      872  0.597260
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# Electrical        1  0.000685
# Id                0  0.000000

# %% [markdown]
# to handle missing data, we'll delete all the variables with missing data, except the variable 'Electrical'. In 'Electrical' we'll just delete the observation with missing data.

# %% [markdown]
#  # Outliers

# %% [markdown]
# we'll standardize the data.

# %% [raw]
# from sklearn.preprocessing import StandardScaler
# sale_scaled = StandardScaler().fit_transform(train['SalePrice'].values.reshape(-1, 1))
# lowRange=sale_scaled[sale_scaled[:,0].argsort()][:10]
# highRange=sale_scaled[sale_scaled[:,0].argsort()][-10:]
# print(f'out range low:\n{lowRange}')
# print(f'out range high:\n{highRange}')

# %% [markdown]
# **Bivariate analysis**

# %% [markdown]
# We already know the following scatter plots by heart. However, when we look to things from a new perspective, there's always something to discover. As Alan Kay said, 'a change in perspective is worth 80 IQ points'.

# %%
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
train.sort_values(by='GrLivArea',ascending = False)[:2]

train = train.drop(train[train['Id']==1299].index)
train = train.drop(train[ train['Id']== 524].index)

# %%
var = 'TotalBsmtSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %% [markdown]
# We have 3 outlier but we I think that  don't effect because
# These homes might be significantly different from the vast majority of houses in the dataset (e.g., much larger, custom-built, or having unique features). If your goal is to model the typical home sale price, including these outliers could skew your model and make it less accurate for predictions on most houses.

# %% [markdown]
# Data analysis

# %%
sns.distplot(train['SalePrice'],fit=norm)
fig= plt.figure()
result=stats.probplot(train['SalePrice'],plot=plt)

# %% [markdown]
# Because line not linear we can transform by take log

# %%
train['SalePrice']=np.log(train['SalePrice'])
sns.distplot( train['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot( train['SalePrice'], plot=plt)

# %% [markdown]
# now become as linear

# %%
sns.distplot( train['GrLivArea'], fit=norm);
fig = plt.figure()
res = stats.probplot( train['GrLivArea'], plot=plt)

# %%
train['GrLivArea']=np.log(train['GrLivArea'])
sns.distplot( train['GrLivArea'], fit=norm);
fig = plt.figure()
res = stats.probplot( train['GrLivArea'], plot=plt)

# %%
sns.distplot( train['TotalBsmtSF'], fit=norm);
fig = plt.figure()
res = stats.probplot( train['TotalBsmtSF'], plot=plt)

# %% [markdown]
# Log transformations are often used to reduce skewness and make data closer to a normal distribution. However, you cannot take the logarithm of zero.  This is the core problem.

# %%
# we do technque convert binary by add one cloumn if area greater than >>1 else = 0
train['HasBsmt'] = pd.Series(len(train['TotalBsmtSF']), index=train.index)
train['HasBsmt'] = 0 
train.loc[train['TotalBsmtSF']>0,'HasBsmt'] = 1

# %%
train.loc[ train['HasBsmt']==1,'TotalBsmtSF'] = np.log ( train['TotalBsmtSF'])

# %%
sns.distplot(train[train['TotalBsmtSF']>0]['TotalBsmtSF'], fit=norm);
fig = plt.figure()
res = stats.probplot(train[train['TotalBsmtSF']>0]['TotalBsmtSF'], plot=plt)

# %%
plt.scatter(train['GrLivArea'], train['SalePrice']);

# %%
plt.scatter(train[train['TotalBsmtSF']>0]['TotalBsmtSF'], train[train['TotalBsmtSF']>0]['SalePrice']);

# %%
train=pd.get_dummies(train)
train
pd.to_cs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 3
#       1 train=pd.get_dummies(train)
#       2 train
# ----> 3 pd.to_cs
#
# AttributeError: module 'pandas' has no attribute 'to_cs'

# %% [markdown]
# # Modeling

# %%
feature=[ 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
       'TotalBsmtSF' , 'FullBath', 'BsmtQual_Ex', 'TotRmsAbvGrd','YearBuilt']
x=train[feature]
y=train['SalePrice']

# %%
#after  salacted feature
algorithms_params = {
    "Linear Regression": {'algorithm': LinearRegression},  # No parameters to tune
    "Ridge Regression": {'algorithm': Ridge, 'param_grid': {'alpha': [0.1, 1.0, 10.0]}},
    "Lasso Regression": {'algorithm': Lasso, 'param_grid': {'alpha': [0.1, 1.0, 10.0]}},
    "Elastic Net": {'algorithm': ElasticNet, 'param_grid': {'alpha': [0.1, 1.0, 10.0], 'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]}},
    "Support Vector Regression": {'algorithm': SVR, 'param_grid': {'C': [0.1, 1.0, 10.0], 'kernel': ['rbf', 'linear']}},
    "Gradient Boosting": {'algorithm': GradientBoostingRegressor, 'param_grid': {'n_estimators': [50, 100], 'learning_rate': [0.01, 0.1]}}
     }
 
def train_and_evaluate_regressors(X, y, algorithms_params, test_size=0.2, random_state=42):
    """
    Trains and evaluates multiple regression algorithms with parameter tuning using GridSearchCV.

    Args:
        X: Features (NumPy array or Pandas DataFrame).
        y: Target variable (NumPy array or Pandas Series).
        algorithms_params: A dictionary where keys are algorithm names and values are dictionaries of hyperparameters to tune.
        test_size: The proportion of the dataset to include in the test split.
        random_state: Controls the random number generation.

    Returns:
        A dictionary containing the trained models and evaluation metrics for each algorithm.
        The fitted scaler.
    """

    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=random_state)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    results = {}

    for name, params in algorithms_params.items():
        print(f"Training and evaluating {name}...")

        algorithm = params['algorithm'] # Get the algorithm class
        param_grid = params.get('param_grid', {})  # Hyperparameters to tune, empty dict if none

        if param_grid: # If there are parameters to tune
            print("Performing Grid Search...")
            grid_search = GridSearchCV(algorithm(), param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1) #Use negative MSE as score for GridSearchCV
            grid_search.fit(X_train_scaled, y_train)
            best_model = grid_search.best_estimator_
            print(f"Best parameters for {name}: {grid_search.best_params_}")
        else: # No hyperparameter tuning needed
            best_model = algorithm().fit(X_train_scaled, y_train) # Train directly if no parameter grid

        y_pred = best_model.predict(X_test_scaled)

        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test, y_pred)

        results[name] = {
            'model': best_model,
            'mse': mse,
            'rmse': rmse,
            'r2': r2,
            'y_pred': y_pred
        }
        print()

        print(f"{name} - MSE: {mse:.4f}, RMSE: {rmse:.4f}, R-squared: {r2:.4f}")

    return results, scaler


 

 
 


 

results, scaler = train_and_evaluate_regressors(x, y, algorithms_params)

# ... (rest of the code for accessing results, plotting, and saving the model remains the same)

best_algorithm = max(results, key=lambda k: results[k]['r2'])
best_model = results[best_algorithm]['model']

 

print(f"\nBest Model: {best_algorithm} " )

# %%
# !pip install h2o
# import h2o
# from h2o.automl import H2OAutoML


# h2o.init()   

 
# data = h2o.import_file(r"D:\data science\project kaggle\home-data-for-ml-course\train.csv")

 
# target = "price"

 
# aml = H2OAutoML(max_models=10, seed=42)  
# aml.train(x=data.drop("SalePrice"), y=target)

 
# best_model = aml.leader

 
# performance = best_model.performance(test_data=data)

# h2o.shutdown()

# %%
# from h2o.automl import H2OAutoML
# import h2o

# h2o.init()  

 
# data = h2o.import_filer(r"D:\data science\project kaggle\home-data-for-ml-course\train.csv")

 
# target = "price"

 
# aml = H2OAutoML(max_models=10, seed=42)  
# aml.train(x=data.drop(target), y=target)

 
# leaderboard = aml.leaderboard
# print("Leaderboard:")
# print(leaderboard)

 
# best_model = aml.leader
 
# print("\nBest Model:")
# print(best_model)

 
# performance_training = best_model.performance(test_data=data)
# print("\nPerformance on Training Data:")
# print(performance_training)
 
 
# test_data = h2o.import_file(r"D:\data science\project kaggle\home-data-for-ml-course\train.csv")
# performance_test = best_model.performance(test_data=test_data)
# print("\nPerformance on Test Data:")
# print(performance_test)

 

 
# variable_importance = best_model.varimp()
# print("\nVariable Importance:")
# print(variable_importance)
# variable_importance.plot() 

 
# if variable_importance is not None and len(variable_importance) > 0:
#     most_important_variable = variable_importance["variable"][0]
#     partial_dependence = best_model.partial_dependence(data=data, cols=[most_important_variable])
#     partial_dependence.plot()

# h2o.shutdown()
